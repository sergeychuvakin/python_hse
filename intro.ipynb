# %% [markdown]
# # lection 1
# 1) Особенности языка
# - достаточно простой синтаксис
# - интерпретируемый
# - приймущественно ОПП
# - есть поддержка функционального программирования
# - GIL (позже про парралелизацию)
# - нативен для работы с данными
# - огромное сообщество
# - множество модулей
# - pandas для работы с табличками (репликация языка R) <br>
# 2) python скрипты
# - работа с bash
# - python как калькулятор
# - IDE<br>
# 3) типы данных
# - int
# - str
# - float
# - list
# - dict (JSON)
# - tuple
# - set
# - bool  <br>
# 4) понятие переменной
# - присвоение
# - операторы (+ - =+ / % ** * ) <br>
# 5) while
# - for
# - while
# - range
# - enumerate
# - zip
# - indexing
# - list,dict,tuple comprehension <br>
# 6) функции
# - def
# - return
# - lambda
# - стек вызовов
# - методы (позже про ООП) <br>
# 7) map, filter <br>
# 8) input()

# %% [markdown]
# # lection 2
# - ООП
# - классы
# - наследование классов
# - методы
# - namespace, scopes, enviroment
# - модули
# - импорт
# - свои модули
# - исключения
# - работа с исключениями try/except
# - генераторы \ итераторы (yeild)
# - PEP8

# %% [markdown]
# ## tasks for lection 1
#
# ### start
#
# 1) написать цикл, который печатает только четные цифры из списка <br>
# 2) написать цикл, который печатает только индексы четных цифр из списка <br>
# 3) написать программу, которая печатает только четное попарное произведение из двух списков <br>
# 4) написать программу, которая печатает только индексы только нечетных попарных произведений из двух списков<br>
#
# ### further
#
# 5) написать программу, которая принимает на вход напечатанное с клавиатуры число и ровно столько раз его печатает<br>
# 6) написать программу, которая принимает вначале число, а затем строку (к примеру имя), здоровается, а затем почаетает это число \*\*2 раз его <br>
# 7) написать алгоритм, который считает, количество уникальных элементов в списке. <br>
# 8) написать программу, которая печатает слово "привет" до тех пор пока с клавиатуры не будет введелно ключевое слово.
#
# #### task*
#
#
# <pre>
# Сочетанием из n элементов по k называется подмножество этих n элементов размера k.
# Два сочетания называются различными, если одно из сочетаний содержит элемент, который не содержит другое.
# Числом сочетаний из n по k называется количество различных сочетаний из n по k. Обозначим это число за C(n, k).
#
# Пример:
# Пусть n = 3, т. е. есть три элемента (1, 2, 3). Пусть k = 2.
# Все различные сочетания из 3 элементов по 2: (1, 2), (1, 3), (2, 3).
# Различных сочетаний три, поэтому C(3, 2) = 3.
#
# Несложно понять, что C(n, 0) = 1, так как из n элементов выбрать 0 можно единственным образом, а именно, ничего не выбрать.
# Также несложно понять, что если k > n, то C(n, k) = 0, так как невозможно, например, из трех элементов выбрать пять.
#
# Для вычисления C(n, k) в других случаях используется следующая рекуррентная формула:
# C(n, k) = C(n - 1, k) + C(n - 1, k - 1).
#
# Реализуйте программу, которая для заданных n и k вычисляет C(n, k).
#
# Вашей программе на вход подается строка, содержащая два целых числа n и k (1 ≤ n ≤ 10, 0 ≤ k ≤ 10).
# Ваша программа должна вывести единственное число: C(n, k).
#
# Примечание:
# Считать два числа n и k вы можете, например, следующим образом:
#
# n, k = map(int, input().split())
#
# Sample Input 1:
#
# 3 2
#
# Sample Output 1:
#
# 3
#
# Sample Input 2:
#
# 10 5
#
# Sample Output 2:
#
# 252
# </pre>
